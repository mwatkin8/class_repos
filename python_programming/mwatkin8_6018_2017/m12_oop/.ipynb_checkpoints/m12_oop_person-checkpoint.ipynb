# %% [markdown]
# # Classes and Object Oriented Programming
# ## Notebook 2
#
# In this notebook you are going to create classes that simulate people. We will be using Pandas to generate the data we will use to create our person objects.

# %%
from nose.tools import assert_equal, assert_true, assert_raises, assert_almost_equal

# %%
import pandas as pd
import gzip
import pickle
import dateutil
import datetime
from dateutil.relativedelta import *
import numpy.random as ra
import math
import random
import seaborn as sns
import numpy as np
import numbers
import uuid

# %% [markdown]
# ## Get Surnames
#
# I have downloaded from the [Census Bureau](https://www.census.gov/topics/population/genealogy/data/2000_surnames.html) a csv file with the surnames and their counts in the 2010 census.

# %% [markdown]
# **Problem 1 (5 points)**: Create a Pandas DataFrame named `surnames` from the file `2010_surnames.csv` that has columns `"name"` and `"count"` where count is greater than 10,000.

# %%
surnames = None
# YOUR CODE HERE
surnames = pd.read_csv('2010_surnames.csv', usecols=['name', 'count'])
surnames = surnames.loc[surnames['count'] > 10000]
surnames.head()
# Out:
#        name    count
# 0     SMITH  2376206
# 1   JOHNSON  1857160
# 2  WILLIAMS  1534042
# 3     BROWN  1380145
# 4     JONES  1362755

# %%
assert_equal(surnames.shape, (3287,2))

# %%
assert_equal(list(surnames.columns), ["name", "count"])

# %% [markdown]
# **Problem 2 (10 points):** Create a new column in `surnames` called `"probability"` that is the probability each name occurs in the sample of names (i.e. the count for that name divided by the sum of all the counts). Sort `surnames` so that the rows increase with `"probability"`.

# %%
# YOUR CODE HERE
def prob(row):
    return row[1] / surnames['count'].sum()
surnames['probability'] = surnames.apply (lambda row: prob(row), axis=1)
surnames = surnames.sort('probability', ascending=True)
surnames.head()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """
#           name  count  probability
# 3286    KASPER  10005     0.000067
# 3285    ZELLER  10006     0.000067
# 3284   SKIPPER  10010     0.000067
# 3283   CARBONE  10012     0.000067
# 3282  LAFFERTY  10014     0.000067

# %%
assert_almost_equal(surnames[surnames["name"] == "YOUNG"]["probability"].values[0], 0.003138555454437736)

# %%
assert_almost_equal(surnames[surnames["name"] == "CHAPMAN"]["probability"].values[0], 0.00083938110990776664)

# %%
assert_true(surnames["probability"][surnames.index[0]] < surnames["probability"][surnames.index[-1]])

# %% [markdown]
# **Problem 3 (xy 5):** Add a column named `"cumulative_probability"` that is for a given name the cumulative sum of all the probabilities for names less common than that name.
#
# The tail of your DataFrame should look like this:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>count</th>
#       <th>probability</th>
#       <th>cumulative_probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>JONES</td>
#       <td>1362755</td>
#       <td>0.009179</td>
#       <td>0.951855</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BROWN</td>
#       <td>1380145</td>
#       <td>0.009296</td>
#       <td>0.961152</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>WILLIAMS</td>
#       <td>1534042</td>
#       <td>0.010333</td>
#       <td>0.971485</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>JOHNSON</td>
#       <td>1857160</td>
#       <td>0.012510</td>
#       <td>0.983994</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>SMITH</td>
#       <td>2376206</td>
#       <td>0.016006</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
#
# **Hint:** There is a Pandas DataFrame/Series method for this.

# %%
# YOUR CODE HERE
surnames['cumulative_probability'] = surnames['probability'].cumsum(axis = 0)
surnames.tail()
# Out:
#        name    count  probability  cumulative_probability
# 4     JONES  1362755     0.009179                0.951855
# 3     BROWN  1380145     0.009296                0.961152
# 2  WILLIAMS  1534042     0.010333                0.971485
# 1   JOHNSON  1857160     0.012510                0.983994
# 0     SMITH  2376206     0.016006                1.000000

# %%
assert_almost_equal(surnames[surnames["name"] == "WEBBER"]["cumulative_probability"].values[0], 0.21867902035776357)

# %%
assert_almost_equal(surnames[surnames["name"] == "JOHNSON"]["cumulative_probability"].values[0], 0.98399423475974246)

# %% [markdown]
# **Problem 4 (15):** Write a function `get_lastname` that takes as an argument your modified DataFrame `surnames` and returns a random name based on name frequency. Here is some pseudo-code for the function
#
# function get_lastname
#
#     Arguments:
#         a positional argument that is a DataFrame with surnames and the cumulative probability for each surname
#         a keyword argument seed with a seed value (default None)
#     Returns: a name
#
#     Set the random number generator seed with seed.
#     Generate a random number (v) between 0 and 1
#     for each row in DataFrame    ask
#        is v < row["cumulative_probability"]?
#            if yes then return the name value in this row
#            if no then continue
#
# There is a faster way to achieve this results that uses Pandas selecting with a boolean DataFrame rather than a for loop:
#
#     Arguments:
#         a positional argument that is a DataFrame with surnames and the cumulative probability for each surname
#         a keyword argument seed with a seed value (default None)
#     Returns: a name
#
#     Set the random number generator seed with seed.
#     Generate a random number (v) between 0 and 1
#
#     Select all the rows in the DataFrame where the cumulative probability is greater than v
#     Select first row in the resulting DataFrame and return the cumulative probability from that row.
#
#
# #### We need the seed argument for testing purposes.

# %%
import random
def get_lastname(surnames, seed=None):
    # YOUR CODE HERE
    random.seed(seed)
    v = random.random()
    for x,row in surnames.iterrows():
        if v < row['cumulative_probability']:
            return row['name']

# %%
assert_equal(get_lastname(surnames, seed=1), 'BATEMAN')

# %%
assert_equal(get_lastname(surnames, seed=356789), 'WEBB')

# %% [markdown]
# ## Get Mortality Data
#
# We are going to simulate patients living and dying. To do this we need the probability of dying for an individual at a given age. This is available through the [Social Security Administration website](https://www.ssa.gov/oact/STATS/table4c6.html). As we learned in the Pandas module, Pandas can read HTML tables. HTML, however, is notoriously messy and I had to do some hacking to get the data cleaned up to a usable state.

# %%
#!pip install lxml

# %%
mortality = pd.read_html("https://www.ssa.gov/oact/STATS/table4c6.html", 
                         skiprows=4, 
                         header=None)[0]
mortality = mortality.iloc[0:120,[1,4]]
mortality.rename(columns=dict(zip(mortality.columns, 
                                  ("Male prob. death", 
                                   "Female prob. death"))), 
                 inplace=True)
mortality.head()
# Out:
#    Male prob. death  Female prob. death
# 0          0.006322            0.005313
# 1          0.000396            0.000346
# 2          0.000282            0.000221
# 3          0.000212            0.000162
# 4          0.000186            0.000131

# %%
#HAD TO ADD FLAVOR='HTML5LIB' TO GET IT TO WORK
mortality = pd.read_html("https://www.ssa.gov/oact/STATS/table4c6.html", 
                         skiprows=4, 
                         header=None, flavor='html5lib')[0]
mortality = mortality.iloc[0:120,[1,4]]
mortality.rename(columns=dict(zip(mortality.columns, 
                                  ("Male prob. death", 
                                   "Female prob. death"))), 
                 inplace=True)
mortality.head()
# Out:
#    Male prob. death  Female prob. death
# 0          0.006322            0.005313
# 1          0.000396            0.000346
# 2          0.000282            0.000221
# 3          0.000212            0.000162
# 4          0.000186            0.000131

# %% [markdown]
# ## Get USA Municipalities
#
# Our people need to live somewhere. I've downloaded a csv file with USA municipalities and their populations (`"PEP_2016_PEPANNRES.csv"`).
#
# [Census Website](https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?src=bkmk)

# %% [markdown]
# **Problem 5 (15 points):**
#
# 1. Use Pandas to read in `PEP_2016_PEPANNRES.csv` into a DataFrame named `municipalities`. The DataFrame should contain the following two columns: "Geography" and "April 1, 2010 - Census". To properly read in the data you will need to use the following keyword argument in `read_csv`:
# ```Python
# encoding="latin1"
# ```
# 2. Use the `r2` regular expression object to replace all matches in the DataFrame with an empty string.
#
# 3. Similar to what we did with `surnames` create a column `"probabilities"` (using the "April 1, 2010 - Census" column), sort the `municipalities` by `"probabilities"` and create a `"cumulative_probability"` column.
#
# Your resulting DataFrame should look like this:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Geography</th>
#       <th>April 1, 2010 - Census</th>
#       <th>probability</th>
#       <th>cumulative_probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9610</th>
#       <td>Goss, Missouri</td>
#       <td>0.0</td>
#       <td>0.000000e+00</td>
#       <td>0.000000e+00</td>
#     </tr>
#     <tr>
#       <th>10665</th>
#       <td>Monowi, Nebraska</td>
#       <td>1.0</td>
#       <td>5.203602e-09</td>
#       <td>5.203602e-09</td>
#     </tr>
#     <tr>
#       <th>10553</th>
#       <td>Gross, Nebraska</td>
#       <td>2.0</td>
#       <td>1.040720e-08</td>
#       <td>1.561081e-08</td>
#     </tr>
#     <tr>
#       <th>14109</th>
#       <td>Lotsee, Oklahoma</td>
#       <td>2.0</td>
#       <td>1.040720e-08</td>
#       <td>2.601801e-08</td>
#     </tr>
#     <tr>
#       <th>16043</th>
#       <td>Hillsview, South Dakota</td>
#       <td>3.0</td>
#       <td>1.561081e-08</td>
#       <td>4.162882e-08</td>
#     </tr>
#   </tbody>
# </table>

# %%
import re
r2 = re.compile(" city| village| town")

# YOUR CODE HERE
#Compile dataframe
municipalities = pd.read_csv('PEP_2016_PEPANNRES.csv', encoding='latin1')

municipalities = municipalities.rename(columns = municipalities.iloc[0])
municipalities = municipalities.reindex(municipalities.index.drop(0))
municipalities = municipalities[['Geography', 'April 1, 2010 - Census']].replace(r2, "", regex=True)
municipalities[['April 1, 2010 - Census']] = municipalities[['April 1, 2010 - Census']].apply(pd.to_numeric)

#Make probability column
def prob(row):
    return row[1] / municipalities['April 1, 2010 - Census'].sum()
municipalities['probability'] = municipalities.apply (lambda row: prob(row), axis=1)
municipalities = municipalities.sort('probability', ascending=True)

#Make cummulative probability column
municipalities['cumulative_probability'] = municipalities['probability'].cumsum(axis = 0)

municipalities.head()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:17: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                      Geography  April 1, 2010 - Census   probability  \
# 9611            Goss, Missouri                     0.0  0.000000e+00
# 10666         Monowi, Nebraska                     1.0  5.203602e-09
# 10554          Gross, Nebraska                     2.0  1.040720e-08
# 14110         Lotsee, Oklahoma                     2.0  1.040720e-08
# 16044  Hillsview, South Dakota                     3.0  1.561081e-08
#
#        cumulative_probability
# 9611             0.000000e+00
# 10666            5.203602e-09
# 10554            1.561081e-08
# 14110            2.601801e-08
# 16044            4.162882e-08

# %%
assert_equal(municipalities.columns.tolist(), 
             ['Geography', 
              'April 1, 2010 - Census', 
              'probability',
              'cumulative_probability'])

# %%
assert_equal(municipalities.iloc[0]["Geography"], "Goss, Missouri")

# %%
assert_equal(municipalities.iloc[3274]["Geography"], "Creston, Washington")

# %% [markdown]
# **Problem 6 (5 points):**
#
# Generalize the `get_lastname` function to return the value in an arbitrary column based on an arbitrary test column.

# %%
def get_random_attribute(df, return_col, 
                         test_col="cumulative_probability",
                         seed=None):
    # YOUR CODE HERE
    random.seed(seed)
    v = random.random()
    attribute = df.loc[df[test_col] > v][return_col].iloc[0]
    
    return attribute

# %%
assert_equal(get_random_attribute(municipalities, 
                                  "Geography",
                                  seed=172),
             'Manassas, Virginia')

# %%
assert_equal(get_random_attribute(surnames, "name",seed=172),"JOHNS")

# %% [markdown]
# ## Age Distribution
# We need distributions for our population ages. Here is information at the [Census Bureau](https://www.census.gov/prod/cen2010/briefs/c2010br-03.pdf). I'm going to just use the geometric distribution in numpy to create a (to me, for this homework) reasonable distribution of ages.

# %%
def get_age(minage=17, maxage=100, p=0.06):
    age = minage+ra.geometric(p,1)[0]
    if age < maxage:
        return age
    else:
        return get_age()
ages = pd.Series([get_age() for i in range(100000)])
print(ages.min(), ages.max())
ages.hist(bins=100)
# Out:
# 18 99

# %% [markdown]
# **Problem 7 (5 points):**
#
# Write a function `get_sex` that takes a positional argument the proportion of the population that is female and returns `"F"` or `"M"` based on that proportion. The keyword argument `seed=None` is needed for testing.
#
# ```Python
# 0.52
# ```

# %%
def get_sex(female_proportion, seed=None):
# YOUR CODE HERE
    random.seed(seed)
    r = random.random()
    if r <= female_proportion:
        return "F"
    else:
        return "M"

# %%
assert_equal(get_sex(0.52, seed=1), "F")

# %%
assert_equal(get_sex(0.1, seed=1), "M")

# %% [markdown]
# ## First Names
#
# **Problem 8 (5 points):**
#
# The Social Security Administration provides the [names of babies](https://www.ssa.gov/oact/babynames/limits.html) born in the United States between 1880 and 2016. For privacy purposes names occuring fewer than 5 times per year are excluded. A dicctionary containing these name, along with ther probabilities and cumulative probabilites is stored in a compressed pickle file `first_names.pickle.gz`. Use Python to read the dictionary into this notebook.

# %%
first_names = None

# YOUR CODE HERE
with gzip.open('first_names.pickle.gz', 'rb') as f:
    first_names = pickle.load(f)

# %%
assert_equal(list(first_names.keys()), 
                          [1880, 1881, 1882, 1883, 1884, 1885, 
                           1886, 1887, 1888, 1889, 1890, 1891, 
                           1892, 1893, 1894, 1895, 1896, 1897, 
                           1898, 1899, 1900, 1901, 1902, 1903, 
                           1904, 1905, 1906, 1907, 1908, 1909, 
                           1910, 1911, 1912, 1913, 1914, 1915, 
                           1916, 1917, 1918, 1919, 1920, 1921, 
                           1922, 1923, 1924, 1925, 1926, 1927, 
                           1928, 1929, 1930, 1931, 1932, 1933, 
                           1934, 1935, 1936, 1937, 1938, 1939, 
                           1940, 1941, 1942, 1943, 1944, 1945, 
                           1946, 1947, 1948, 1949, 1950, 1951, 
                           1952, 1953, 1954, 1955, 1956, 1957, 
                           1958, 1959, 1960, 1961, 1962, 1963, 
                           1964, 1965, 1966, 1967, 1968, 1969, 
                           1970, 1971, 1972, 1973, 1974, 1975, 
                           1976, 1977, 1978, 1979, 1980, 1981, 
                           1982, 1983, 1984, 1985, 1986, 1987, 
                           1988, 1989, 1990, 1991, 1992, 1993, 
                           1994, 1995, 1996, 1997, 1998, 1999, 
                           2000, 2001, 2002, 2003, 2004, 2005, 
                           2006, 2007, 2008, 2009, 2010, 2011, 
                           2012, 2013, 2014, 2015, 2016])

# %% [markdown]
# **Problem 9 (15 points):**
#
# Complete the code for the person class defined below:
#
#
# ```Python
# class person(object):
#     """
#     person class.
#     """
#     __sexes = ('M', 'F')
#     def __init__(self, name = "John",
#                  dob = "",
#                  sex = 'F'):
#         """Contructor. Names no arguments."""
#         self.name = name
#         self.dob = dob
#         self.sex = sex
#
#
#     @property
#     def name(self):
#         ???
#     @name.setter
#     def name(self,name):
#         ???
#     @property
#     def age(self):
#         """
#         Returns the person's age in years as an integer.
#
#         Age is computed using the different between the
#         date of birth and the current date.
#         """
#         ???
#     @property
#     def dob(self):
#         return self.__dob
#     @dob.setter
#     def dob(self, dob):
#         self.__dob = dateutil.parser.parse(dob).date()
#     @property
#     def sex(self):
#         ???
#     @sex.setter
#     def sex(self, value):
#         sex = value.upper()[0]
#         if sex not in self.__sexes:
#             raise ValueError("%s: invalid sex specification"%sex)
#         self.__sex = sex
#
#     def __str__(self):
#         ???
# ```

# %%
# YOUR CODE HERE
class person(object):
    """
    person class. 
    """
    __sexes = ('M', 'F')
    def __init__(self, name = "John",
                 dob = "",
                 sex = 'F'):
        """Contructor. Names no arguments."""
        self.name = name
        self.dob = dob
        self.sex = sex


    @property
    def name(self):
        return self.__name
    @name.setter
    def name(self,name):
        if type(name) is str:
            self.__name = name
        else:
            print("Bad name")
            raise AttributeError
    @property
    def age(self):
        """
        Returns the person's age in years as an integer.

        Age is computed using the different between the 
        date of birth and the current date.
        """
        return datetime.date.today().year - self.dob.year

    @property
    def dob(self):
        return self.__dob
    @dob.setter
    def dob(self, dob):
        self.__dob = dateutil.parser.parse(dob).date()
    @property
    def sex(self):
        return self.__sex
    @sex.setter
    def sex(self, value):
        sex = value.upper()[0]
        if sex not in self.__sexes:
            raise ValueError("%s: invalid sex specification"%sex)
        self.__sex = sex

    def __str__(self):
        return self.name + " " + self.sex + " " + str(self.age) + " " + str(self.dob)

# %%
test_person = person(name="Earl", dob="Feb 28, 1929", sex="M")
assert_true("Earl" in test_person.__str__())

# %%
test_person = person(name="Earl", dob="Feb 28, 1929", sex="M")
assert_true("88" in test_person.__str__())

# %%
test_person = person(name="Donna", dob="March 15, 1947", sex="F")
assert_equal(test_person.age, 70)

# %%
assert_raises(ValueError, person, name="Ziggy", 
                                  dob="01/08/1947", 
              sex="Other")

# %%
assert_raises(AttributeError, person, name=1947, sex="M", dob="01/08/1947")
# Out:
# Bad name

# %% [markdown]
# **Problem 10 (30 points):**
#
# Define a class `participant` that inherits from `person`. The class adds the following attributes and properties. For properties, store the actual value in a private variable:
#
# * `deceased`: a boolean property set initially to False
#     * Define getter/setter properties
# * `dod`: a property
#     * The actual value is a `datetime.date` object stored as a private attribute
#     * The getter property returns the date in an appropriately formated string
#     * The setter property accepts either a string or a datetime.date object
# * `residence`: a string property indicating a municipality in the USA.
#     * * Define getter/setter properties
# * `__study_start`: a datetime.date object initialized to the current date
#     * Initialize in the constructor
#     * Define a getter property (def study_start) but not a setter (cannot be modified)
# * `__time_in_study`: a `dateutil` `relativedelta` object
#     * Define a getter property that returns the number of days in the study as an integer
# * `__studyid`: An integer generated with the `uuid` library.
#     * Initialize in the constructor
#     * Define a getter property but not a setter (cannot be modified)
#
# In addition to the @property and @xyz.setter methods, the class should implement the following methods:
#
# * `increment_study_time`: accepts a `relativedelta` object and increments the `__time_in_study` attribute.
# * `dies`: sets `deceased` to `True` and sets `dod` to the study start date plus the time in the study
# * `__repr__`
# * `__str__`

# %%
# YOUR CODE HERE
class participant(person):
      
    def __init__(self, name="", dob="", sex="", enrollment_date="", deceased=False, dod="", residence="", studyid=uuid.uuid1().int):
        """Contructor. Names no arguments."""
             
        person.__init__(self, name, dob, sex)
        
        self.deceased = deceased
        self.dod = dod
        self.residence = residence
        
        if enrollment_date == "":
            self.__study_start = datetime.datetime.now().date()
        else:
            self.__study_start = dateutil.parser.parse(enrollment_date).date()
            
        self.__time_in_study = relativedelta()
        self.__studyid = studyid
        
    @property
    def age(self):
        td = self.__study_start + self.__time_in_study - self.dob
        return {"years":td.days//365, "months":td.days%365//30}
        
    @property
    def deceased(self):
        return self.__deceased
    @deceased.setter
    def deceased(self,deceased):
        if type(deceased) is bool:
            self.__deceased = deceased
        else:
            print("Bad deceased")
            raise AttributeError
            
    @property
    def dod(self):
        return self.__dod
    @dod.setter
    def dod(self, dod):
        if dod == "":
            self.__dod = datetime.datetime.now().date()
        elif type(dod) == str:
            self.__dod = dateutil.parser.parse(dod).date()
        else:
            self.__dod = dod
        
    @property
    def residence(self):
        return self.__residence
    @residence.setter
    def residence(self, residence):
        if type(residence) is str:
            self.__residence = residence
        else:
            print("Bad residence")
            raise AttributeError
            
    @property
    def study_start(self):
        return self.__study_start
        
    @property
    def days_in_study(self):
        return ((self.__study_start + self.__time_in_study) - self.__study_start).days
            
    @property
    def studyid(self):
        return self.__studyid
    
    def increment_study_time(self, obj): 
        if not self.deceased:
            self.__time_in_study += obj
    
    def dies(self): 
        #sets deceased to True and sets dod to the study start date plus the time in the study
        self.deceased = True
        self.__dod = self.study_start + datetime.timedelta(days=self.days_in_study)    
        
    def __repr__(self):
         return str(type(self)) + self.__str__()

    def __str__(self):
        return self.name + " " + self.sex + " " + str(self.age) + " " + str(self.dob) + " - " + str(self.dod) + " " + self.residence + " " + str(self.days_in_study) + "days in study " + " studyid: " + str(self.studyid)

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
assert_true(isinstance(p1,person))

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
p1.increment_study_time(relativedelta(months=+24))
assert_true(p1.days_in_study, 730)

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
p1.increment_study_time(relativedelta(months=+36))
p1.dies()
assert_equal(p1.age, {'months': 5, 'years': 52})

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
p1.increment_study_time(relativedelta(months=+36))
p1.dies()
assert_equal(p1.deceased, True)

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian Chapman", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
p1.increment_study_time(relativedelta(months=+12))
assert_equal(p1.deceased, False)

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian Chapman", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
assert_true("Chapman" in p1.__str__())
#assert_equal(p1.deceased, False)

# %%
p1= participant(residence="Salt Lake City", 
                name="Brian Chapman", 
                dob="5/24/1968",
                enrollment_date = "October 28, 2017",
                sex='male')
p1.increment_study_time(relativedelta(months=+6))
assert_true("182" in p1.__repr__())

# %% [markdown]
# **Problem 11 (25 points):**
#
# Complete and correct the function `generateRandomPersonAttributes` so that it properly returns a `participant` object with randomly determined attributes
# ```Python
# def generateRandomPersonAttributes(surnames, first_names,
#                                    municipalities,
#                                    proportion_female=0.52):
#     sex = get_sex
#     age = get_age
#     year = datetime.datetime.now().year-???
#     dob = (datetime.date(datetime.datetime.now.year-age, 1,1)+\
#         relativedelta(days=+random.randint(0,???))).strftime("%B %d, %Y")
#     f_name = get_random_attribute(first_names???, ???)
#     l_name = get_random_attribute(surnames, ???).capitalize
#     residence = get_random_attribute(municipalities, ???)
#     return participant(residence=residence,
#                 name="??? ???"%(f_name, l_name),
#                 dob=???,
#                 sex=sex)
# ```

# %%
# YOUR CODE HERE
def generateRandomPersonAttributes(surnames, first_names, 
                                   municipalities,
                                   proportion_female=0.52):
    random.seed(None)
    sex = get_sex(proportion_female)
    age = get_age()
    sexes = ['M', 'F']
        
    year = datetime.datetime.now().year-age
    dob = (datetime.date(datetime.datetime.now().year-age, 1,1)+\
        relativedelta(days=+random.randint(0,364))).strftime("%B %d, %Y")
    f_name = get_random_attribute(first_names[year][sex], 'name')
    l_name = get_random_attribute(surnames, 'name').capitalize()
    residence = get_random_attribute(municipalities, 'Geography')
    return participant(residence=residence, 
                name="%s %s"%(f_name, l_name), 
                dob=dob,
                sex=sex)

# %%
participants = \
[generateRandomPersonAttributes(surnames, 
                                first_names, 
                                municipalities) for i in range(5)]
assert_equal(len(participants),5)

# %%
participants = \
[generateRandomPersonAttributes(surnames, 
                                first_names, 
                                municipalities) for i in range(5)]
for p in participants:
    assert_true(isinstance(p,participant))

# %%
participants = \
[generateRandomPersonAttributes(surnames, 
                                first_names, 
                                municipalities) for i in range(1000)]

# %%
pd.Series([p.age["years"] for p in participants]).hist(bins=100)

# %% [markdown]
# ## A Function to Run the "Study"

# %%
def increment_study(participants, mortality, unit=10):
    delta = 365/unit
    mkeys = {"M":"Male prob. death", "F":"Female prob. death"}
    for p in participants:
        p.increment_study_time(relativedelta(days=+unit))
        if random.random()< mortality.iloc[p.age["years"]][mkeys[p.sex]]/delta:
            p.dies()
    return None

# %%
while True:
    living = [p for p in participants if not p.deceased]
    if len(living)%200 == 0:
        print(len(living))
    if not living:
        break
    increment_study(living, mortality)
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 800
# 400
# 400
# 400
# 400
# 400
# 400
# 0

# %%
sns.distplot([p.age["years"] for p in participants])

# %%
pd.Series([p.age["years"] for p in participants]).hist(bins=100)

# %%
np.mean([p.age["years"] for p in participants if p.sex == "M"])
np.mean([p.age["years"] for p in participants if p.sex == "F"])
# Out:
# 82.649541284403668

# %% [markdown]
# **Problem 12 (15 points):** Write a function `get_participant_df` that takes a list of participant objects and returns a Pandas DataFrame witht he following columns:
# ['Age', 'Days in Study', 'First Name', 'Last Name', 'Sex', 'State'].
#
# Each row in the DataFrame corresponds to a particular participant with the column values the appropriate values from a participant object.

# %%
# YOUR CODE HERE
def get_participant_df(participants):
    col_list = ['Age', 'Days in Study', 'First Name', 'Last Name', 'Sex', 'State']
    df = pd.DataFrame(columns=col_list)
    row = 0
    print(participants)
    for p in participants:
        df.loc[row,'Age'] = p.age['years'] + p.age['months'] / 12
        
        df.loc[row,'Days in Study'] = p.days_in_study
        
        names = p.name.split()
        df.loc[row,"First Name"] = names[0]
        df.loc[row,"Last Name"] = names[1]
            
        df.loc[row,"Sex"] = p.sex
        
        residence = p.residence.split(",")
        if len(residence) > 1:
            df.loc[row,"State"] = residence[1]
        else:
            df.loc[row,"State"] = residence[0]
            
        row += 1
                
    return df

# %%
pdf = get_participant_df(participants)
# Out:
# [<class '__main__.participant'>Caroline Ortega F {'months': 4, 'years': 67} 1989-01-03 - 2056-05-05 Fullerton, California 14050days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Deborah Diaz F {'months': 4, 'years': 61} 1970-07-16 - 2031-11-23 Rogers, Arkansas 5120days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Adrienne James F {'months': 0, 'years': 76} 1991-04-08 - 2067-03-29 Quitman, Georgia 18030days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Christopher Hendrickson M {'months': 7, 'years': 98} 1995-11-06 - 2094-05-26 Canton, Illinois 27950days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Conor Mcgregor M {'months': 7, 'years': 95} 1998-01-27 - 2093-08-09 Laconia, New Hampshire 27660days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Melissa Hankins F {'months': 10, 'years': 86} 1981-12-08 - 2068-09-19 Fayetteville, North Carolina 18570days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Joseph Bennett M {'months': 1, 'years': 78} 1989-04-24 - 2067-05-28 Jacksonville, Florida 18090days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Matthew Walker M {'months': 9, 'years': 74} 1993-10-02 - 2068-06-21 Spokane, Washington 18480days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Celeste Williams F {'months': 2, 'years': 62} 1984-05-05 - 2046-06-27 Atlanta, Georgia 10450days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Raul Christian M {'months': 11, 'years': 91} 1992-09-18 - 2084-08-16 Franklin, Tennessee 24380days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Angelica Caron F {'months': 0, 'years': 80} 1994-03-02 - 2074-02-20 Chicago, Illinois 20550days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>William Hostetler M {'months': 8, 'years': 67} 1988-07-01 - 2056-03-06 Los Angeles, California 13990days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Austin Barton M {'months': 7, 'years': 57} 1990-03-05 - 2047-10-10 Fayetteville, North Carolina 10920days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Shawn Harlan M {'months': 8, 'years': 86} 1995-09-05 - 2082-04-19 Long Beach, California 23530days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Kyle Jett M {'months': 3, 'years': 37} 1990-09-26 - 2027-12-24 Phoenix, Arizona 3690days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Michael Fox M {'months': 11, 'years': 84} 1961-03-04 - 2046-01-28 Farmington Hills, Michigan 10300days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Scott Allen M {'months': 5, 'years': 84} 1979-04-04 - 2063-08-27 Rapid City, South Dakota 16720days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Brian Logan M {'months': 3, 'years': 85} 1978-09-16 - 2063-12-15 Chester, New York 16830days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Mary Cannon F {'months': 3, 'years': 90} 1984-03-23 - 2074-06-20 South Plainfield borough, New Jersey 20670days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Vincent Barnes M {'months': 5, 'years': 66} 1978-02-11 - 2044-07-17 Montevideo, Minnesota 9740days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Daniel Harvey M {'months': 7, 'years': 94} 1991-09-26 - 2086-04-18 Spring Valley, Illinois 24990days in study  studyid: 248679673439518827056091505352005386262, <class '__ ...

# %%
assert_equal(set(pdf.columns),
             set(['Age', 'First Name', 'Days in Study',
                  'Last Name', 'Sex', 'State']))

# %%
isinstance(pdf[pdf["Sex"]=="M"]["Age"].mean(), numbers.Real)
# Out:
# True

# %%
print(pdf)
# Out:
#          Age Days in Study   First Name    Last Name Sex            State
# 0    67.3333         14050     Caroline       Ortega   F       California
# 1    61.3333          5120      Deborah         Diaz   F         Arkansas
# 2         76         18030     Adrienne        James   F          Georgia
# 3    98.5833         27950  Christopher  Hendrickson   M         Illinois
# 4    95.5833         27660        Conor     Mcgregor   M    New Hampshire
# 5    86.8333         18570      Melissa      Hankins   F   North Carolina
# 6    78.0833         18090       Joseph      Bennett   M          Florida
# 7      74.75         18480      Matthew       Walker   M       Washington
# 8    62.1667         10450      Celeste     Williams   F          Georgia
# 9    91.9167         24380         Raul    Christian   M        Tennessee
# 10        80         20550     Angelica        Caron   F         Illinois
# 11   67.6667         13990      William    Hostetler   M       California
# 12   57.5833         10920       Austin       Barton   M   North Carolina
# 13   86.6667         23530        Shawn       Harlan   M       California
# 14     37.25          3690         Kyle         Jett   M          Arizona
# 15   84.9167         10300      Michael          Fox   M         Michigan
# 16   84.4167         16720        Scott        Allen   M     South Dakota
# 17     85.25         16830        Brian        Logan   M         New York
# 18     90.25         20670         Mary       Cannon   F       New Jersey
# 19   66.4167          9740      Vincent       Barnes   M        Minnesota
# 20   94.5833         24990       Daniel       Harvey   M         Illinois
# 21   93.1667         24590       Jessie         Loyd   F       California
# 22   85.6667         22270        Jesus      Edwards   M          Georgia
# 23        39          6930        Corey        Jones   M     South Dakota
# 24      74.5         16450        Jaime     Schaefer   M     Pennsylvania
# 25   75.8333         17750       Joshua       Salmon   M         Kentucky
# 26   90.4167         24680     Nicholas        Brown   M           Oregon
# 27        88         21640    Priscilla        Hayes   F            Texas
# 28        79         18870       Manuel       Yeager   M       California
# 29   63.3333          4310        Renee        Smith   F         Illinois
# ..       ...           ...          ...          ...  ..              ...
# 970  77.6667         16700       Daniel        North   M       New Jersey
# 971  98.6667         27520        Megan    Edmondson   F            Texas
# 972  96.0833         20220      Shannon        White   F            Texas
# 973  91.0833         25740       Alicia        Nance   F            Texas
# 974  90.1667         21780      Jessica        Evans   F        Wisconsin
# 975    71.75         17540       Joshua     Mcdaniel   M            Texas
# 976    84.75         16060         Paul       Connor   M       New Jersey
# 977    78.25         20090      Crystal         Dale   F         Illinois
# 978  72.4167         18710        James     Phillips   M          Florida
# 979  80.5833          6360      Delores        Cheng   F        Minnesota
# 980  83.1667         23240      Crystal       Alonzo   F          Florida
# 981  80.1667         13210      William       Conner   M          Florida
# 982  90.3333          3740       Ronald     Martinez   M     Pennsylvania
# 983  89.0833         23420       Raquel       Myrick   F         New York
# 984    74.75         18700       Summer    Mcclellan   F       California
# 985     85.5         12300          Amy      Hubbard   F         Nebraska
# 986     65.5          5870       Rhonda       Wilson   F       California
# 987  67.9167          2470       Sandra        Cross   F          Florida
# 988   107.75         26150      Raymond        Singh   M         Colorado
# 989    89.75         22150      Vanessa       Haynes   F          Florida
# 990  92.6667         26960        Emily       Harris   F       California
# 991  82.1667         16890         Beth       Brooks   F             Ohio
# 992  93.5833         20770  Christopher         Cole   M            Texas
# 993       89         23820       Ashton         Case   F       California
# 994       94         25130       Ashley        Amaya   F         Colorado
# 995  89.5833         24890      Kirsten     Williams   F            Texas
# 996    86.25         23430      Patrick     Campbell   M       Washington
# 997  81.3333         16280       Carrie       Romero   F          Indiana
# 998    90.25         23740    Elizabeth    Rodriguez   F         Illinois
# 999  82.5833         18560        Emily    Robertson   F       New Mexico
#
# [1000 rows x 6 columns]

# %%
assert_true(isinstance(pdf.iloc[0]["Days in Study"], numbers.Integral))

# %%
sns.kdeplot(data=pdf[pdf["Sex"]=="M"]["Age"], 
            label="Male", color="Blue")
sns.kdeplot(data=pdf[pdf["Sex"]=="F"]["Age"],
            label="Female", color="pink")

# %%
sns.boxplot(x="Sex", y="Age", data=pdf);

# %%
sns.countplot(x="Sex", data=pdf);

# %%
sns.countplot(x="Sex", data=pdf[pdf["Age"]>90]);

# %% [markdown]
# **Problem 13 (10 points):** Write a function `create_obituaries` that takes a list of participant objects, a filename, writes out obituaries for each participant in ascending order by date of death. Your file should look something like this:
#
# Jerry Peck, age 82, of Detroit Lakes, Minnesota, died April 06, 2018
# John Conley, age 96, of Kokomo, Indiana, died May 16, 2018
# Jeffery Meyer, age 32, of Wilson's Mills, North Carolina, died May 26, 2018
# Kenneth Jackson, age 54, of Portland, Oregon, died August 04, 2018
# Heather Johnson, age 46, of Sunrise, Florida, died August 24, 2018
# Kristen Holland, age 31, of Town and Country, Missouri, died September 13, 2018

# %%
# YOUR CODE HERE
def create_obituaries(participants, filename):
    df = get_participant_df(participants)
    row = 0
    for p in participants:
        df.loc[row,'Full Name'] = p.name
        df.loc[row,'State'] = p.residence
        df.loc[row,'Death'] = p.dod
        row+=1
        
    df['Death'] = pd.to_datetime(df.Death)
    df = df.sort_values(by='Death')
        
    with open(filename, 'w') as out:
        for index,row in df.iterrows():
            out.write(row['Full Name'] + ", age " + str(int(row['Age'])) + ", of " + row['State'] + ", died " + row['Death'].strftime('%B %d, %Y') + "\n")

# %%
rdate = re.compile(r"""(?P<month>[A-Z][a-z]+) (?P<day>\d{2,2}), (?P<year>\d{4,4})""")
fname = "test_obits.txt"
create_obituaries(participants, fname)
with open(fname) as f0:
    data = f0.readlines()
os.remove(fname)
m0 = rdate.search(data[0])
ml = rdate.search(data[-1])
assert_true(int(m0.group("year")) < int(ml.group("year")))
# Out:
# [<class '__main__.participant'>Caroline Ortega F {'months': 4, 'years': 67} 1989-01-03 - 2056-05-05 Fullerton, California 14050days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Deborah Diaz F {'months': 4, 'years': 61} 1970-07-16 - 2031-11-23 Rogers, Arkansas 5120days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Adrienne James F {'months': 0, 'years': 76} 1991-04-08 - 2067-03-29 Quitman, Georgia 18030days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Christopher Hendrickson M {'months': 7, 'years': 98} 1995-11-06 - 2094-05-26 Canton, Illinois 27950days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Conor Mcgregor M {'months': 7, 'years': 95} 1998-01-27 - 2093-08-09 Laconia, New Hampshire 27660days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Melissa Hankins F {'months': 10, 'years': 86} 1981-12-08 - 2068-09-19 Fayetteville, North Carolina 18570days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Joseph Bennett M {'months': 1, 'years': 78} 1989-04-24 - 2067-05-28 Jacksonville, Florida 18090days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Matthew Walker M {'months': 9, 'years': 74} 1993-10-02 - 2068-06-21 Spokane, Washington 18480days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Celeste Williams F {'months': 2, 'years': 62} 1984-05-05 - 2046-06-27 Atlanta, Georgia 10450days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Raul Christian M {'months': 11, 'years': 91} 1992-09-18 - 2084-08-16 Franklin, Tennessee 24380days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Angelica Caron F {'months': 0, 'years': 80} 1994-03-02 - 2074-02-20 Chicago, Illinois 20550days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>William Hostetler M {'months': 8, 'years': 67} 1988-07-01 - 2056-03-06 Los Angeles, California 13990days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Austin Barton M {'months': 7, 'years': 57} 1990-03-05 - 2047-10-10 Fayetteville, North Carolina 10920days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Shawn Harlan M {'months': 8, 'years': 86} 1995-09-05 - 2082-04-19 Long Beach, California 23530days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Kyle Jett M {'months': 3, 'years': 37} 1990-09-26 - 2027-12-24 Phoenix, Arizona 3690days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Michael Fox M {'months': 11, 'years': 84} 1961-03-04 - 2046-01-28 Farmington Hills, Michigan 10300days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Scott Allen M {'months': 5, 'years': 84} 1979-04-04 - 2063-08-27 Rapid City, South Dakota 16720days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Brian Logan M {'months': 3, 'years': 85} 1978-09-16 - 2063-12-15 Chester, New York 16830days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Mary Cannon F {'months': 3, 'years': 90} 1984-03-23 - 2074-06-20 South Plainfield borough, New Jersey 20670days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Vincent Barnes M {'months': 5, 'years': 66} 1978-02-11 - 2044-07-17 Montevideo, Minnesota 9740days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Daniel Harvey M {'months': 7, 'years': 94} 1991-09-26 - 2086-04-18 Spring Valley, Illinois 24990days in study  studyid: 248679673439518827056091505352005386262, <class '__ ...

# %%
import os
fname = "test_obits.txt"
create_obituaries(participants, fname)

with open(fname) as f0:
    data = f0.readlines()
os.remove(fname)
m0 = rdate.search(data[0])
ml = rdate.search(data[-1])
assert_equal(len(data), len(participants))
# Out:
# [<class '__main__.participant'>Caroline Ortega F {'months': 4, 'years': 67} 1989-01-03 - 2056-05-05 Fullerton, California 14050days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Deborah Diaz F {'months': 4, 'years': 61} 1970-07-16 - 2031-11-23 Rogers, Arkansas 5120days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Adrienne James F {'months': 0, 'years': 76} 1991-04-08 - 2067-03-29 Quitman, Georgia 18030days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Christopher Hendrickson M {'months': 7, 'years': 98} 1995-11-06 - 2094-05-26 Canton, Illinois 27950days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Conor Mcgregor M {'months': 7, 'years': 95} 1998-01-27 - 2093-08-09 Laconia, New Hampshire 27660days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Melissa Hankins F {'months': 10, 'years': 86} 1981-12-08 - 2068-09-19 Fayetteville, North Carolina 18570days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Joseph Bennett M {'months': 1, 'years': 78} 1989-04-24 - 2067-05-28 Jacksonville, Florida 18090days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Matthew Walker M {'months': 9, 'years': 74} 1993-10-02 - 2068-06-21 Spokane, Washington 18480days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Celeste Williams F {'months': 2, 'years': 62} 1984-05-05 - 2046-06-27 Atlanta, Georgia 10450days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Raul Christian M {'months': 11, 'years': 91} 1992-09-18 - 2084-08-16 Franklin, Tennessee 24380days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Angelica Caron F {'months': 0, 'years': 80} 1994-03-02 - 2074-02-20 Chicago, Illinois 20550days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>William Hostetler M {'months': 8, 'years': 67} 1988-07-01 - 2056-03-06 Los Angeles, California 13990days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Austin Barton M {'months': 7, 'years': 57} 1990-03-05 - 2047-10-10 Fayetteville, North Carolina 10920days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Shawn Harlan M {'months': 8, 'years': 86} 1995-09-05 - 2082-04-19 Long Beach, California 23530days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Kyle Jett M {'months': 3, 'years': 37} 1990-09-26 - 2027-12-24 Phoenix, Arizona 3690days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Michael Fox M {'months': 11, 'years': 84} 1961-03-04 - 2046-01-28 Farmington Hills, Michigan 10300days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Scott Allen M {'months': 5, 'years': 84} 1979-04-04 - 2063-08-27 Rapid City, South Dakota 16720days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Brian Logan M {'months': 3, 'years': 85} 1978-09-16 - 2063-12-15 Chester, New York 16830days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Mary Cannon F {'months': 3, 'years': 90} 1984-03-23 - 2074-06-20 South Plainfield borough, New Jersey 20670days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Vincent Barnes M {'months': 5, 'years': 66} 1978-02-11 - 2044-07-17 Montevideo, Minnesota 9740days in study  studyid: 248679673439518827056091505352005386262, <class '__main__.participant'>Daniel Harvey M {'months': 7, 'years': 94} 1991-09-26 - 2086-04-18 Spring Valley, Illinois 24990days in study  studyid: 248679673439518827056091505352005386262, <class '__ ...
