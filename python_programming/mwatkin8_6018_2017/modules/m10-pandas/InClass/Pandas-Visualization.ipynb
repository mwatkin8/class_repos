# %% [markdown]
# # [Pandas-Visualization](http://pandas.pydata.org/)
#
# Pandas has a rich set of built-in visualizations that are based on [matplotlib](http://matplotlib.org/), an old but de factor standard for plotting and visualization in Python.
#
# In addition to the built-in visualizations, almost all Python visualization packages, such as [seaborn](https://stanford.edu/~mwaskom/software/seaborn/) and [bokeh](http://bokeh.pydata.org/en/latest/), can work directly with Pandas data structures.
#
# In this notebook, I demonstrate some of the built-in visualization tools.

# %%
% matplotlib nbagg

# %%
import os
import sqlite3 as sqlite
import time
DATADIR = os.path.join("..", "Resources")

# %%
import pandas as pd

# %%
import numpy as np

# %%
elevationA = pd.read_table(os.path.join("../", "Resources","elevation2.txt"),
                           thousands=",",index_col='State')

# %%
elevationA
# Out:
#                 Unnamed: 0  Rank  Highest elevation  Lowest elevation  \
# State
# Colorado                 0     1              14440              3315
# Wyoming                  1     2              13804              3099
# Utah                     2     3              13528              2000
# New Mexico               3     4              13161              2842
# Nevada                   4     5              13140               479
# Idaho                    5     6              12662               710
# Arizona                  6     7              12633                70
# Montana                  7     8              12799              1800
# Oregon                   8     9              11239                 0
# Hawaii                   9    10              13796                 0
# California              10    11              14494              -282
# Nebraska                11    12               5424               840
# South Dakota            12    13               7242               966
# Kansas                  13    14               4039               679
# Alaska                  14    15              20320                 0
# North Dakota            15    16               3506               750
# Washington              16    17              14410                 0
# Texas                   17    18               8749                 0
# West Virginia           18    19               4863               240
# Oklahoma                19    20               4973               289
# Minnesota               20    21               2301               602
# Pennsylvania            21    22               3213                 0
# Iowa                    22    23               1670               480
# Wisconsin               23    24               1951               581
# New Hampshire           24    25               6288                 0
# New York                25    26               5344                 0
# Vermont                 26    27               4393                95
# Virginia                27    28               5729                 0
# Tennessee               28    29               6643               178
# Michigan                29    30               1979               572
# Ohio                    30    31               1549               455
# Missouri                31    32               1772               230
# Kentucky                32    33               4139               257
# North Carolina          33    34               6684                 0
# Indiana                 34    35               1257               320
# Arkansas                35    36               2753                55
# Maine                   36    37               5276                 0
# Georgia                 37    38               4784                 0
# Illinois                38    39               1235               279
# Massachusetts           39    40               3487                 0
# Alabama                 40    41               2407                 0
# Connecticut             41    42               2380                 0
# South Carolina          42    43               3560                 0
# Maryland                43    44               3360                 0
# Mississippi             44    45                806                 0
# New Jersey              45    46               1803                 0
# Rhode Island            46    47                812                 0
# Louisiana               47    48                535                -8
# Florida                 48    49                345                 0
# Delaware                49    50                450                 0
#
#                 Average elevation
# State
# Colorado                     6800
# Wyoming                      6700
# Utah                         6100
# New Mexico                   5700
# Nevada                       5500
# Idaho                        5000
# Arizona                      4100
# Montana                      3400
# Oregon                       3300
# Hawaii                       3030
# California                   2900
# Nebraska                     2600
# South Dakota                 2200
# Kansas                       2000
# Alaska                       1900
# North Dakota                 1900
# Washington                   1700
# Texas                        1700
# West Virginia                1500
# Oklahoma                     1300
# Minnesota                    1200
# Pennsylvania                 1100
# Iowa                         1100
# Wisconsin                    1050
# New Hampshire                1000
# New York                     1000
# Vermont                      1000
# Virginia                      950
# Tennessee                     900
# Michigan                      900
# Ohio                          850
# Missouri                      800
# Kentucky                      750
# North Carolina                700
# Indiana                       700
# Arkansas                      650
# Maine                         600
# Georgia                       600
# Illinois                      600
# Massachusetts                 500
# Alabama                       500
# Connecticut                   500
# South Carolina                350
# Maryland                      350
# Mississippi                   300
# New Jersey                    250
# Rhode Island                  200
# Louisiana                     100
# Florida                       100
# Delaware                       60

# %% [markdown]
# ### Basic line plot

# %%
print (elevationA['Highest elevation'])
# Out:
# State
# Colorado          14440
# Wyoming           13804
# Utah              13528
# New Mexico        13161
# Nevada            13140
# Idaho             12662
# Arizona           12633
# Montana           12799
# Oregon            11239
# Hawaii            13796
# California        14494
# Nebraska           5424
# South Dakota       7242
# Kansas             4039
# Alaska            20320
# North Dakota       3506
# Washington        14410
# Texas              8749
# West Virginia      4863
# Oklahoma           4973
# Minnesota          2301
# Pennsylvania       3213
# Iowa               1670
# Wisconsin          1951
# New Hampshire      6288
# New York           5344
# Vermont            4393
# Virginia           5729
# Tennessee          6643
# Michigan           1979
# Ohio               1549
# Missouri           1772
# Kentucky           4139
# North Carolina     6684
# Indiana            1257
# Arkansas           2753
# Maine              5276
# Georgia            4784
# Illinois           1235
# Massachusetts      3487
# Alabama            2407
# Connecticut        2380
# South Carolina     3560
# Maryland           3360
# Mississippi         806
# New Jersey         1803
# Rhode Island        812
# Louisiana           535
# Florida             345
# Delaware            450
# Name: Highest elevation, dtype: int64

# %%
elevationA["Average elevation"].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Bar plot

# %%
elevationA["Highest elevation"].plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bp = pd.read_csv(os.path.join(DATADIR,"abp_all.csv"),
                 na_values=[0]).dropna()
bp
# Out:
#         Unnamed: 0  VALUE1NUM VALUE1UOM  VALUE2NUM VALUE2UOM
# 4              4.0       78.0      mmHg       49.0      mmHg
# 5              5.0       73.0      mmHg       47.0      mmHg
# 6              6.0       77.0      mmHg       51.0      mmHg
# 7              7.0       88.0      mmHg       54.0      mmHg
# 8              8.0       73.0      mmHg       43.0      mmHg
# 9              9.0       84.0      mmHg       53.0      mmHg
# 10            10.0       89.0      mmHg       57.0      mmHg
# 11            11.0      100.0      mmHg       60.0      mmHg
# 12            12.0      123.0      mmHg       66.0      mmHg
# 13            13.0      125.0      mmHg       66.0      mmHg
# 14            14.0      132.0      mmHg       71.0      mmHg
# 15            15.0       88.0      mmHg       55.0      mmHg
# 16            16.0      102.0      mmHg       63.0      mmHg
# 17            17.0       99.0      mmHg       63.0      mmHg
# 18            18.0      124.0      mmHg       70.0      mmHg
# 19            19.0      129.0      mmHg       74.0      mmHg
# 20            20.0      122.0      mmHg       71.0      mmHg
# 21            21.0      114.0      mmHg       69.0      mmHg
# 22            22.0       96.0      mmHg       59.0      mmHg
# 23            23.0      112.0      mmHg       66.0      mmHg
# 24            24.0       93.0      mmHg       57.0      mmHg
# 25            25.0       92.0      mmHg       55.0      mmHg
# 26            26.0       94.0      mmHg       56.0      mmHg
# 27            27.0      100.0      mmHg       57.0      mmHg
# 28            28.0      116.0      mmHg       63.0      mmHg
# 29            29.0      113.0      mmHg       61.0      mmHg
# 30            30.0      115.0      mmHg       64.0      mmHg
# 31            31.0       98.0      mmHg       66.0      mmHg
# 32            32.0       95.0      mmHg       55.0      mmHg
# 33            33.0      119.0      mmHg       66.0      mmHg
# ...            ...        ...       ...        ...       ...
# 852862    852862.0      146.0      mmHg      117.0      mmHg
# 852863    852863.0      142.0      mmHg       69.0      mmHg
# 852864    852864.0      135.0      mmHg       65.0      mmHg
# 852865    852865.0      135.0      mmHg       64.0      mmHg
# 852866    852866.0      134.0      mmHg       63.0      mmHg
# 852867    852867.0      124.0      mmHg       77.0      mmHg
# 852868    852868.0      134.0      mmHg       72.0      mmHg
# 852869    852869.0      131.0      mmHg       93.0      mmHg
# 852870    852870.0      124.0      mmHg       98.0      mmHg
# 852871    852871.0      131.0      mmHg      122.0      mmHg
# 852872    852872.0      133.0      mmHg      125.0      mmHg
# 852873    852873.0      145.0      mmHg       75.0      mmHg
# 852874    852874.0      125.0      mmHg       56.0      mmHg
# 852875    852875.0      145.0      mmHg       63.0      mmHg
# 852876    852876.0      141.0      mmHg       61.0      mmHg
# 852877    852877.0      126.0      mmHg       60.0      mmHg
# 852878    852878.0      123.0      mmHg       60.0      mmHg
# 852881    852881.0       83.0      mmHg       67.0      mmHg
# 852882    852882.0       82.0      mmHg       67.0      mmHg
# 852883    852883.0       85.0      mmHg       71.0      mmHg
# 852884    852884.0       85.0      mmHg       71.0      mmHg
# 852885    852885.0       96.0      mmHg       78.0      mmHg
# 852886    852886.0       84.0      mmHg       72.0      mmHg
# 852887    852887.0       99.0      mmHg       84.0      mmHg
# 852888    852888.0       93.0      mmHg       80.0      mmHg
# 852889    852889.0       77.0      mmHg       69.0      mmHg
# 852890    852890.0       73.0      mmHg       65.0      mmHg
# 852891    852891.0       61.0      mmHg       56.0      mmHg
# 852892    852892.0       95.0      mmHg       85.0      mmHg
# 852894    852894.0       87.0      mmHg       83.0      mmHg
#
# [846588 rows x 5 columns]

# %%
bp.hist(column=["VALUE1NUM","VALUE2NUM"], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b081e86a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b08169588>]], dtype=object)

# %% [markdown]
# ## We can create numpy arrays from text data
# ### We can generate a data frame from numpy arrays

# %%
systolic = np.genfromtxt(os.path.join(DATADIR,"systolic.txt"),
                         delimiter=",")
diastolic = np.genfromtxt(os.path.join(DATADIR,"diastolic.txt"),
                         delimiter=",")

# %%
blood_pressure = pd.DataFrame.from_dict({'systolic':systolic,'diastolic':diastolic})

# %%
blood_pressure = blood_pressure[blood_pressure != 0].dropna()

# %%
blood_pressure
# Out:
#      diastolic  systolic
# 0         46.0     139.0
# 2         49.0      78.0
# 3         47.0      73.0
# 4         51.0      77.0
# 5         54.0      88.0
# 6         43.0      73.0
# 7         53.0      84.0
# 8         57.0      89.0
# 9         60.0     100.0
# 10        66.0     123.0
# 11        66.0     125.0
# 12        71.0     132.0
# 13        55.0      88.0
# 14        63.0     102.0
# 15        63.0      99.0
# 16        70.0     124.0
# 17        74.0     129.0
# 18        71.0     122.0
# 19        69.0     114.0
# 20        59.0      96.0
# 21        66.0     112.0
# 22        57.0      93.0
# 23        55.0      92.0
# 24        56.0      94.0
# 25        57.0     100.0
# 26        63.0     116.0
# 27        61.0     113.0
# 28        64.0     115.0
# 29        66.0      98.0
# 30        55.0      95.0
# ..         ...       ...
# 970       53.0     109.0
# 971       53.0     111.0
# 972       52.0     107.0
# 973       51.0     106.0
# 974       52.0     107.0
# 975       52.0     107.0
# 976       53.0     111.0
# 977       50.0     105.0
# 978       51.0     104.0
# 979       52.0     106.0
# 980       51.0     104.0
# 981       52.0     106.0
# 982       42.0      94.0
# 983       43.0      94.0
# 984       39.0      85.0
# 985       46.0      99.0
# 986       55.0     106.0
# 987       58.0     111.0
# 988       55.0     106.0
# 989       55.0     105.0
# 990       49.0      93.0
# 991       49.0      91.0
# 992       52.0      93.0
# 993       59.0      99.0
# 994       60.0      98.0
# 995       60.0      96.0
# 996       58.0      93.0
# 997       60.0      95.0
# 998       59.0      93.0
# 999       59.0      89.0
#
# [979 rows x 2 columns]

# %% [markdown]
# ### We can make histograms with ``plot()``

# %%
blood_pressure.plot(kind="hist", alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
blood_pressure.plot(kind="hist", bins=100, 
                    colors = ['orange','black'],alpha=0.75)
# Out:
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py:983: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Kernel-Density Estimates

# %%
blood_pressure.plot(kind="kde")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Box plots

# %%
blood_pressure.plot(kind="box")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Scatter plots

# %%
blood_pressure.plot(kind='scatter',x='diastolic',y='systolic')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
blood_pressure.plot(kind='hexbin',
                    x='diastolic',
                    y='systolic',
                   gridsize=25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(blood_pressure,diagonal='kde')
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af40138d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af3ffde48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af3f55d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af3f99668>]], dtype=object)
