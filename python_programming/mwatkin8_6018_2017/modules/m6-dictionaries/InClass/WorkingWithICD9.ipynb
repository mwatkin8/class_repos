# %% [markdown]
# # Working with [ICD9](https://www.cdc.gov/nchs/icd/icd9.htm) Data

# %%
# %matplotlib inline

# %%
import pickle
from collections import defaultdict
from nose.tools import assert_equals

# %%
with open("icd9.pickle","rb") as f0:
    icd9_data = pickle.load(f0)

# %% [markdown]
# ## What does our data look like?

# %%
icd9_data[:5]
# Out:
# ((56, '198.3', 'SECONDARY MALIGNANT NEOPLASM OF BRAIN AND SPINAL C'),
#  (56, '162.8', 'MALIGNANT NEOPLASM OF OTHER PARTS OF BRONCHUS OR L'),
#  (56, '531.40', 'CHRONIC OR UNSPECIFIED GASTRIC ULCER WITH HEMORRHA'),
#  (56, '276.1', 'HYPOSMOLALITY AND/OR HYPONATREMIA'),
#  (56, '428.0', 'CONGESTIVE HEART FAILURE UNSPECIFIED'))

# %%
for d in icd9_data:
    try:
        if "HEP" in d[2]:
            print(d)
    except Exception as Error:
        pass
# Out:
# (78, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (106, 'V02.62', 'CARRIER OR SUSPECTED CARRIER OF HEPATITIS C')
# (124, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (117, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (117, '070.44', 'CHR HEPAT C W/ HEP COMA                 \r')
# (117, '572.4', 'HEPATORENAL SYNDROME                    \r')
# (390, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (433, '070.32', 'CHRON VIR HEP B W/O COMA                \r')
# (433, '070.54', 'CHR HEPAT C W/O HEP COMA                \r')
# (433, '070.30', 'VIR HEP B W/O COM, HEP D                \r')
# (433, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (590, '571.1', 'ACUTE ALCOHOLIC HEPATITIS')
# (634, '572.4', 'HEPATORENAL SYNDROME                    \r')
# (940, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (940, '155.1', 'MALIGNANT NEOPLASM OF INTRAHEPATIC BILE DUCTS')
# (1106, '070.32', 'CHRON VIR HEP B W/O COMA                \r')
# (1100, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (1120, '571.1', 'ACUTE ALCOHOLIC HEPATITIS')
# (1245, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (1284, '572.2', 'HEPATIC COMA')
# (1329, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (1357, '572.2', 'HEPATIC COMA')
# (1357, '572.2', 'HEPATIC COMA                            \r')
# (1357, '572.2', 'HEPATIC COMA                            \r')
# (1380, '572.4', 'HEPATORENAL SYNDROME')
# (1380, '572.2', 'HEPATIC COMA')
# (1494, '572.2', 'HEPATIC COMA')
# (1453, '572.2', 'HEPATIC COMA                            \r')
# (1470, '571.1', 'ACUTE ALCOHOLIC HEPATITIS')
# (1470, '572.4', 'HEPATORENAL SYNDROME')
# (1470, '070.70', 'UNSPECIFIED VIRAL HEPATI                \r')
# (1571, '571.1', 'AC ALCOHOLIC HEPATITIS                  \r')
# (1598, '573.3', 'HEPATITIS UNSPECIFIED')
# (1882, '070.32', 'CHRONIC VIRAL HEPATITIS B WITHOUT HEPATIC COMA WIT')
# (1905, '573.3', 'HEPATITIS UNSPECIFIED')
# (1950, '070.32', 'CHRONIC VIRAL HEPATITIS B WITHOUT HEPATIC COMA WIT')
# (1987, '572.2', 'HEPATIC COMA')
# (2177, '572.2', 'HEPATIC COMA')
# (2195, '572.2', 'HEPATIC COMA')
# (2262, '573.3', 'HEPATITIS UNSPECIFIED')
# (2268, '572.2', 'HEPATIC COMA                            \r')
# (2268, '155.1', 'MALIGNANT NEOPLASM OF INTRAHEPATIC BILE DUCTS')
# (2328, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (2483, '070.51', 'ACUTE OR UNSPECIFIED HEPATITIS C WITHOUT HEPATIC C')
# (2478, '572.4', 'HEPATORENAL SYNDROME')
# (2478, '572.2', 'HEPATIC COMA')
# (2493, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (2570, '070.54', 'CHRONIC HEPATITIS C WITHOUT HEPATIC COMA')
# (2512, '070.54', 'CHR HEPAT C W/O HEP COMA                \r')

# %% [markdown]
# ### Each element of `icd9_data` is a tuple with three elements
# 1. A patient id
# 1. An ICD9 code
# 1. The label for that ICD9 code

# %% [markdown]
# #### Create a dictionary named `icd9_map` with keys ICD9 code and values the ICD9 label
#
# strip extra white spaces

# %%
# YOUR CODE HERE
icd9_map = {}
for d in icd9_data:
    try:
        key = d[1]
        val = " ".join(d[2].split())
        icd9_map[key] = val
        
    except Exception as Error:
        pass
   
print (icd9_map)
#raise NotImplementedError()
# Out:
# {'861.21': 'CONTUSION OF LUNG WITHOUT OPEN WOUND INTO THORAX', 'V10.00': 'HX OF GI MALIGNANCY NOS', '305.1': 'TOBACCO USE DISORDER', '196.1': 'SECONDARY AND UNSPECIFIED MALIGNANT NEOPLASM OF IN', '428.23': 'ACUTE ON CHR SYSTO HRT', '415.19': 'OTHER PULMONARY EMBOLISM AND INFARCTION', '611.0': 'INFLAMMATORY DISEASE OF BREAST', '568.81': 'HEMOPERITONEUM (NONTRAUMATIC)', '070.51': 'ACUTE OR UNSPECIFIED HEPATITIS C WITHOUT HEPATIC C', '518.5': 'PULMONARY INSUFFICIENCY FOLLOWING TRAUMA AND SURGE', '203.00': 'MULTIPLE MYELOMA WITHOUT REMISSION', 'V10.46': 'PERSONAL HISTORY OF MALIGNANT NEOPLASM OF PROSTATE', '438.89': 'OTHER LATE EFFECTS OF CEREBROVASCULAR DISEASE', '335.20': 'AMYOTROPHIC LATERAL SCLEROSIS', '423.8': 'OTHER SPECIFIED DISEASES OF PERICARDIUM', '560.2': 'VOLVULUS', '747.0': 'PATENT DUCTUS ARTERIOSUS', '441.1': 'THORACIC ANEURYSM RUPTURED', '053.9': 'HERPES ZOSTER NOS', '573.3': 'HEPATITIS UNSPECIFIED', '812.00': 'FRACTURE OF UNSPECIFIED PART OF UPPER END OF HUMER', '769': 'RESPIRATORY DISTRESS SYNDROME IN NEWBORN', '070.32': 'CHRONIC VIRAL HEPATITIS B WITHOUT HEPATIC COMA WIT', 'V64.41': 'LAPAROSCOPIC SURGICAL PROCEDURE CONVERTED TO OPEN', '426.0': 'ATRIOVENTRICULAR BLOCK COMPLETE', '250.50': 'DIABETES MELLITUS WITH OPHTHALMIC MANIFESTATIONS T', '255.4': 'CORTICOADRENAL INSUFFICIENCY', '397.0': 'DISEASES OF TRICUSPID VALVE', '198.5': 'SECONDARY MALIGNANT NEOPLASM OF BONE AND BONE MARR', '529.0': 'GLOSSITIS', '997.62': 'INFECTION (CHRONIC) OF AMPUTATION STUMP', '576.2': 'OBSTRUCTION OF BILE DUCT', '197.1': 'SECONDARY MALIGNANT NEOPLASM OF MEDIASTINUM', '349.82': 'TOXIC ENCEPHALOPATHY', '458.8': 'OTHER SPECIFIED HYPOTENSION', '723.4': 'BRACHIAL NEURITIS OR RADICULITIS NOS', '344.00': 'QUADRIPLEGIA UNSPECIFIED', '250.60': 'DIABETES MELLITUS WITH NEUROLOGICAL MANIFESTATIONS', '300.3': 'OBSESSIVE-COMPULSIVE DISORDERS', 'V09.0': 'INFECTION WITH MICROORGANISMS RESISTANT TO PENICIL', '511.0': 'PLEURISY WITHOUT EFFUSION OR CURRENT TUBERCULOSIS', '276.3': 'ALKALOSIS', '414.04': 'CORONARY ATHEROSCLEROSIS OF ARTERY BYPASS GRAFT', '357.4': 'POLYNEUROPATHY IN OTHER DISEASES CLASSIFIED ELSEWH', '250.00': 'DIABETES MELLITUS WITHOUT COMPLICATION TYPE II OR', '070.44': 'CHR HEPAT C W/ HEP COMA', '238.7': 'LYMPHOPROLIFERAT DIS NOS', '286.6': 'DEFIBRINATION SYNDROME', '244.0': 'POSTSURGICAL HYPOTHYROIDISM', '482.9': 'BACTERIAL PNEUMONIA UNSPECIFIED', '303.90': 'OTHER AND UNSPECIFIED ALCOHOL DEPENDENCE UNSPECIFI', '910.0': 'ABRASION OR FRICTION BURN OF FACE NECK AND SCALP E', '269.9': 'UNSPECIFIED NUTRITIONAL DEFICIENCY', '426.7': 'ANOMALOUS ATRIOVENTRICULAR EXCITATION', '162.5': 'MALIGNANT NEOPLASM OF LOWER LOBE BRONCHUS OR LUNG', '434.11': 'CEREBRAL EMBOLISM WITH CEREBRAL INFARCTION', '416.9': 'CHRONIC PULMONARY HEART DISEASE UNSPECIFIED', '411.0': 'POSTMYOCARDIAL INFARCTION SYNDROME', 'E931.9': 'OTHER AND UNSPECIFIED ANTI-INFECTIVES CAUSING ADVE', '737.41': 'KYPHOSIS IN OTH DIS', '250.70': 'DIABETES W/PERIPHERAL CI', '512.1': 'IATROGENIC PNEUMOTHORAX', '782.0': 'DISTURBANCE OF SKIN SENSATION', '574.50': 'CALCULUS OF BILE DUCT WITHOUT CHOLECYSTITIS WITHOU', '414.00': 'CORNARY ATHERO-VESL NOS', 'V10.04': 'HX OF GASTRIC MALIGNANCY', '591': 'HYDRONEPHROSIS', '786.05': 'SHORTNESS OF BREATH', '562.11': 'DIVERTICULITIS OF COLON (WITHOUT HEMORRHAGE)', '293.0': 'ACUTE DELIRIUM', '303.00': 'ACUTE ALCOHOLIC INTOXICATION IN ALCOHOLISM UNSPECI', '191.9': 'MALIGNANT NEOPLASM OF BRAIN UNSPECIFIED SITE', 'V09.91': 'INF DRUG-RESIST W/ RESIS', '414.10': 'ANEURYSM OF HEART (WALL)', 'V10.79': 'PERSONAL HISTORY OF OTHER LYMPHATIC AND HEMATOPOIE', '250.11': 'DIABETES MELLITUS WITH KETOACIDOSIS TYPE I NOT STA', '410.21': 'ACUTE MYOCARDIAL INFARCTION OF INFEROLATERAL WALL', 'E878.8': 'ABN REACT-SURG PROC NEC', 'V45.81': 'AORTOCORONARY BYPASS', '997.1': 'SURG COMPL-HEART', '784.5': 'OTHER SPEECH DISTURBANCE', '289.82': 'SECONDARY HYPERCOAGULABLE STATE', '398.91': 'RHEUMATIC HEART FAILURE (CONGESTIVE)', '430': 'SUBARACHNOID HEMORRHAGE', '294.10': 'DEMENTIA IN C ...

# %%
icd9_patients = defaultdict(list)
patient_diagnoses = defaultdict(list)

# %% [markdown]
# ### How many patients are there for each diagnosis?
#
# Create a list named `icd9_patients_list` sorted by the number of patients per diagnosis.

# %%
icd9_patients = defaultdict(list)
# YOUR CODE HERE
icd9_patients_list = []
for d in icd9_data:
    if dicd9_patients_list


#raise NotImplementedError()
# Out:
# defaultdict(<class 'list'>, {})

# %%
import random
d,p = random.choice(icd9_patients_list)
print(d,len(p),sep="\n")
print(icd9_patients["V12.59"])
for d,p in icd9_patients.items():
    if "HX" in d:
        print(d,len(p))

# %%
assert_equals(len(icd9_patients["V12.59"]),5)
assert_equals(len(icd9_patients["572.2"]),12)

# %% [markdown]
# #### Loop through  `icd9_patients_list`
# 1. for each element in `icd9_patients_list` print the ICD9 label corresponding to the code and the number of patients with each diagnosis.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### How many diagnoses does each patient have?

# %%
patient_diagnoses = defaultdict(list)
# YOUR CODE HERE
raise NotImplementedError()

# %%
for p, d in patient_diagnoses_list:
    print(p)
    print(d) # replace with len(d)
    print("\n")

# %%
assert_equals(len(patient_diagnoses[2512]),49)
assert_equals(len(patient_diagnoses[353]),56)
assert_equals(len(patient_diagnoses_list[0][1]),125)
assert_equals(len(patient_diagnoses_list[45][1]),23)
